# %% [markdown]
# ## Step -1: Business Problem
# Create a predictive model that can help a species of a penguin based on physical attributes, that we can used that model to help researches classify penguins in the field, instead of needing an experienced biologist.

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('penguins_size.csv')
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# ## Step -3: Data Preprocessing
# EDA

# %%
continuous = ['culmen_length_mm', 'culmen_depth_mm',
       'flipper_length_mm', 'body_mass_g']
discrete = ['species', 'island', 'sex']

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
df['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
df['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
df.describe(include='all')
# Out:
#        species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# count      344     344        342.000000       342.000000         342.000000
# unique       3       3               NaN              NaN                NaN
# top     Adelie  Biscoe               NaN              NaN                NaN
# freq       152     168               NaN              NaN                NaN
# mean       NaN     NaN         43.921930        17.151170         200.915205
# std        NaN     NaN          5.459584         1.974793          14.061714
# min        NaN     NaN         32.100000        13.100000         172.000000
# 25%        NaN     NaN         39.225000        15.600000         190.000000
# 50%        NaN     NaN         44.450000        17.300000         197.000000
# 75%        NaN     NaN         48.500000        18.700000         213.000000
# max        NaN     NaN         59.600000        21.500000         231.000000
#
#         body_mass_g   sex
# count    342.000000   334
# unique          NaN     3
# top             NaN  MALE
# freq            NaN   168
# mean    4201.754386   NaN
# std      801.954536   NaN
# min     2700.000000   NaN
# 25%     3550.000000   NaN
# 50%     4050.000000   NaN
# 75%     4750.000000   NaN
# max     6300.000000   NaN

# %%
plt.figure(figsize=(5, 4))
sns.scatterplot(x='culmen_length_mm', y='culmen_depth_mm', data=df, hue='species')
plt.show()

# %%
sns.pairplot(df, hue='species')
plt.show()

# %% [markdown]
# ## based on my this scatter plot, I will apply decision tree

# %%
df['sex'].unique()
# Out:
# array(['MALE', 'FEMALE', nan, '.'], dtype=object)

# %%
df['sex'].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# .           1
# Name: count, dtype: int64

# %% [markdown]
# #### we will replace sex unqiue value with 'MALE' because there are more numbers of male

# %%
df['sex'].replace('.', 'MALE', inplace=True)
df['sex'].unique()
# Out:
# array(['MALE', 'FEMALE', nan], dtype=object)

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
df['culmen_length_mm'].fillna(df['culmen_length_mm'].mean(), inplace=True)
df['culmen_depth_mm'].fillna(df['culmen_depth_mm'].mean(), inplace=True)
df['flipper_length_mm'].fillna(df['flipper_length_mm'].mean(), inplace=True)
df['body_mass_g'].fillna(df['flipper_length_mm'].mean(), inplace=True)
df['sex'].fillna(df['sex'].mode()[0], inplace=True)

# %% [markdown]
# #### Encoding
# as we can see, we applied encoing only on input variable not on output variable (on species) because obn output variable, we should not do encoding

# %%
X = pd.get_dummies(df.drop('species', axis=1), drop_first=True)
y = df['species']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X = le.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 from sklearn.preprocessing import LabelEncoder
#       2 le = LabelEncoder()
# ----> 3 X = le.fit_transform(X)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     147             *data_to_wrap[1:],
#     148         )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\preprocessing\_label.py:116, in LabelEncoder.fit_transform(self, y)
#     103 def fit_transform(self, y):
#     104     """Fit label encoder and return encoded labels.
#     105
#     106     Parameters
#    (...)
#     114         Encoded labels.
#     115     """
# --> 116     y = column_or_1d(y, warn=True)
#     117     self.classes_, y = _unique(y, return_inverse=True)
#     118     return y
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1192, in column_or_1d(y, dtype, warn)
#    1183         warnings.warn(
#    1184             "A column-vector y was passed when a 1d array was"
#    1185             " expected. Please change the shape of y to "
#    (...)
#    1188             stacklevel=2,
#    1189         )
#    1190     return _asarray_with_order(xp.reshape(y, -1), order="C", xp=xp)
# -> 1192 raise ValueError(
#    1193     "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1194 )
#
# ValueError: y should be a 1d array, got an array of shape (344, 7) instead.

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %% [markdown]
# #### Train/ Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=6)

# %% [markdown]
# ## Step -4, 5: Modelling & Evaluation

# %% [markdown]
# # Logistic Regression

# %%
# Modeling
from sklearn.linear_model import LogisticRegression
model1 = LogisticRegression()
model1.fit(X_train, y_train)

# Prediction
ypred_train = model1.predict(X_train)
ypred_test = model1.predict(X_test)

# Evaluation
from sklearn.metrics import accuracy_score
print('Train accuracy:', accuracy_score(y_train, ypred_train))
print('Test accuracy:', accuracy_score(y_test, ypred_test))

# cross va;iation
from sklearn.model_selection import cross_val_score
print('Cross Validation:', cross_val_score(model1, X_train, y_train, cv=5, scoring='accuracy').mean())
# Out:
# Train accuracy: 0.9818181818181818
# Test accuracy: 1.0
# Cross Validation: 0.9818181818181818

# %% [markdown]
# ### Roc curve

# %%
from sklearn.metrics import roc_curve, auc, RocCurveDisplay
fpr, tpr, thrs = roc_curve(y_test, ypred_test)
roc_auc = auc(fpr, tpr)
RocCurveDisplay(fpr = fpr, tpr=tpr, roc_auc=roc_auc).plot()
plt.show()
print(roc_auc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 from sklearn.metrics import roc_curve, auc, RocCurveDisplay
# ----> 2 fpr, tpr, thrs = roc_curve(y_test, ypred_test)
#       3 roc_auc = auc(fpr, tpr)
#       4 RocCurveDisplay(fpr = fpr, tpr=tpr, roc_auc=roc_auc).plot()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_ranking.py:992, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     904 def roc_curve(
#     905     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#     906 ):
#     907     """Compute Receiver operating characteristic (ROC).
#     908
#     909     Note: this implementation is restricted to the binary classification task.
#    (...)
#     990     array([1.8 , 0.8 , 0.4 , 0.35, 0.1 ])
#     991     """
# --> 992     fps, tps, thresholds = _binary_clf_curve(
#     993         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#     994     )
#     996     # Attempt to drop thresholds corresponding to points in between and
#     997     # collinear with other points. These are always suboptimal and do not
#     998     # appear on a plotted ROC curve (and thus do not affect the AUC).
#    (...)
#    1003     # but does not drop more complicated cases like fps = [1, 3, 7],
#    1004     # tps = [1, 2, 4]; there is no harm in keeping too many thresholds.
#    1005     if drop_intermediate and len(fps) > 2:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_ranking.py:749, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     747 y_type = type_of_target(y_true, input_name="y_true")
#     748 if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
# --> 749     raise ValueError("{0} format is not supported".format(y_type))
#     751 check_consistent_length(y_true, y_score, sample_weight)
#     752 y_true = column_or_1d(y_true)
#
# ValueError: multiclass format is not supported

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, ypred_test)
cm

# %% [markdown]
# # Decision Tree Classifier
# #### with default Hyperparameters
#
# default parameter is 'gini', max_depth = 'None', min_samples_split=3
#
# ### it means here tree has grown completely fully

# %%
# Modelling
from sklearn.tree import DecisionTreeClassifier
dt_default = DecisionTreeClassifier()
dt_default.fit(X_train, y_train)

# Prediction
ypred_train = dt_default.predict(X_train)

# Evaluation
from sklearn.metrics import accuracy_score
print('Train accuracy:', accuracy_score(ypred_train, y_train))

from sklearn.model_selection import cross_val_score
print('Cross Validation:', cross_val_score(dt_default, X, y, cv=5).mean())

ypred_test = dt_default.predict(X_test)
print('Test accuracy:', accuracy_score(ypred_test, y_test))
# Out:
# Train accuracy: 1.0
# Cross Validation: 0.9679454390451834
# Test accuracy: 1.0

# %% [markdown]
# #### Visualize the tree

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(24, 12), dpi=300)
# dpi = density per inch

plot_tree(dt_default,
         filled=True)
plt.show()

# %%
X.head(1)
# Out:
#    culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0              39.1             18.7              181.0       3750.0
#
#    island_Dream  island_Torgersen  sex_MALE
# 0         False              True      True

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(24, 12), dpi=300)

plot_tree(dt_default,
         filled=True,
         feature_names=['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm',
       'body_mass_g', 'island_Dream', 'island_Torgersen', 'sex_MALE'],
         class_names=['Adelie', 'Chinstrap', 'Gentoo'])
plt.show()

# %%
X_train.head(2)
# Out:
#      culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 209              49.3             19.9              203.0       4050.0
# 103              37.8             20.0              190.0       4250.0
#
#      island_Dream  island_Torgersen  sex_MALE
# 209          True             False      True
# 103         False             False      True

# %% [markdown]
# ### when I will do fit on X_train, y_train it will calculate gini of each and every column.
#
# ### and out of all gini value whichever the value will be highest that will be selected as a root node.

# %%
len(X_train.columns)
# Out:
# 7

# %%
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen          39.10000         18.70000         181.000000
# 1    Adelie  Torgersen          39.50000         17.40000         186.000000
# 2    Adelie  Torgersen          40.30000         18.00000         195.000000
# 3    Adelie  Torgersen          43.92193         17.15117         200.915205
# 4    Adelie  Torgersen          36.70000         19.30000         193.000000
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe          43.92193         17.15117         200.915205
# 340  Gentoo     Biscoe          46.80000         14.30000         215.000000
# 341  Gentoo     Biscoe          50.40000         15.70000         222.000000
# 342  Gentoo     Biscoe          45.20000         14.80000         212.000000
# 343  Gentoo     Biscoe          49.90000         16.10000         213.000000
#
#      body_mass_g     sex
# 0    3750.000000    MALE
# 1    3800.000000  FEMALE
# 2    3250.000000  FEMALE
# 3     200.915205    MALE
# 4    3450.000000  FEMALE
# ..           ...     ...
# 339   200.915205    MALE
# 340  4850.000000  FEMALE
# 341  5750.000000    MALE
# 342  5200.000000  FEMALE
# 343  5400.000000    MALE
#
# [344 rows x 7 columns]

# %% [markdown]
# ### Hyperparameter Tuning for Decision Tree Classifier
#
# #### in decision tree you will get different accuracy so give random_state = 0 in DT model
# ## random state is used to lock the data

# %%
from sklearn.model_selection import GridSearchCV

# model
estimator = DecisionTreeClassifier(random_state=0)

# parameters (which you want to tune and identify the best)
param_grid = {'criterion':['gini', 'entropy'],
             'max_depth':[1, 2, 3, 4, 5], 'min_samples_split':[45, 14]}

grid = GridSearchCV(estimator, param_grid, cv=5, scoring='accuracy')
grid.fit(X_train, y_train)
grid.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'min_samples_split': 14}

# %%
grid.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_split=14, random_state=0)

# %% [markdown]
# #### Importance of each feature given by this model

# %%
data = grid.best_estimator_.feature_importances_
data
# Out:
# array([0.34238292, 0.05506425, 0.5754201 , 0.        , 0.02713274,
#        0.        , 0.        ])

# %%
feats = pd.DataFrame(data, index=X.columns, columns=['Feature Importance'])
feats
# Out:
#                    Feature Importance
# culmen_length_mm             0.342383
# culmen_depth_mm              0.055064
# flipper_length_mm            0.575420
# body_mass_g                  0.000000
# island_Dream                 0.027133
# island_Torgersen             0.000000
# sex_MALE                     0.000000

# %%
feats_imp = feats[feats['Feature Importance']>0]
feats_imp
# Out:
#                    Feature Importance
# culmen_length_mm             0.342383
# culmen_depth_mm              0.055064
# flipper_length_mm            0.575420
# island_Dream                 0.027133

# %%
feats_imp = feats[feats['Feature Importance']>0]
important_features_list = feats_imp.index.to_list()
important_features_list
# Out:
# ['culmen_length_mm', 'culmen_depth_mm', 'flipper_length_mm', 'island_Dream']

# %% [markdown]
# ## Final DecisionTree Model
# #### with best hyperparameter & with important features

# %%
# input with important features
X_imp = X[important_features_list]

# train-test-split
X_train, X_test, y_train, y_test = train_test_split(X_imp, y, test_size=0.2, random_state=6)

# Model with best hyperparameters
final_dt_model = DecisionTreeClassifier(criterion='gini', max_depth=5, random_state=0)
final_dt_model.fit(X_train, y_train)

ypred_train = final_dt_model.predict(X_train)
ypred_test = final_dt_model.predict(X_test)

# Evaluation
print('Train accuracy:', accuracy_score(ypred_train, y_train))
print('Test accuracy:', accuracy_score(ypred_test, y_test))
print('Cross Validation Score:', cross_val_score(final_dt_model, X_imp, y, cv=5).mean())
# Out:
# Train accuracy: 0.9963636363636363
# Test accuracy: 1.0
# Cross Validation Score: 0.9766837169650469

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, ypred_test)
# Out:
# array([[30,  0,  0],
#        [ 0, 18,  0],
#        [ 0,  0, 21]], dtype=int64)

# %%
dt_default.predict([[50, 20, 200, 4500, 1, 0, 0]])
# 1, 0 = island encoding
# 0 = gender encoding
# Out:
# array(['Chinstrap'], dtype=object)

# %%
final_dt_model.feature_importances_
# Out:
# array([0.32986127, 0.07590424, 0.56891573, 0.02531876])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00        30
#    Chinstrap       1.00      1.00      1.00        18
#       Gentoo       1.00      1.00      1.00        21
#
#     accuracy                           1.00        69
#    macro avg       1.00      1.00      1.00        69
# weighted avg       1.00      1.00      1.00        69

# %%
from sklearn.metrics import recall_score, precision_score, f1_score
print('Precision Score:', precision_score(y_test,ypred_test, average=None))
print('Recal Score:', recall_score(y_test,ypred_test, average=None))
print('F1 Score:', f1_score(y_test,ypred_test, average=None))
# Out:
# Precision Score: [1. 1. 1.]
# Recal Score: [1. 1. 1.]
# F1 Score: [1. 1. 1.]

# %%
from sklearn.metrics import recall_score, precision_score, f1_score
print('Precision Score:', precision_score(y_test,ypred_test, average='macro'))
print('Recal Score:', recall_score(y_test,ypred_test, average='macro'))
print('F1 Score:', f1_score(y_test,ypred_test, average='macro'))
# Out:
# Precision Score: 1.0
# Recal Score: 1.0
# F1 Score: 1.0

# %%
from sklearn.metrics import recall_score, precision_score, f1_score
print('Precision Score:', precision_score(y_test,ypred_test, average='weighted'))
print('Recal Score:', recall_score(y_test,ypred_test, average='weighted'))
print('F1 Score:', f1_score(y_test,ypred_test, average='weighted'))
# Out:
# Precision Score: 1.0
# Recal Score: 1.0
# F1 Score: 1.0

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#       Adelie       1.00      1.00      1.00        30
#    Chinstrap       1.00      1.00      1.00        18
#       Gentoo       1.00      1.00      1.00        21
#
#     accuracy                           1.00        69
#    macro avg       1.00      1.00      1.00        69
# weighted avg       1.00      1.00      1.00        69
